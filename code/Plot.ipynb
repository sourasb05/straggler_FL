# %% [markdown]
# # Experiments on MNIST non-IID

# %%
import pickle

# %% [markdown]
# MOOACS+Fedprox+non-IID

# %%
pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

# %%
train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
''' 

data = {'training loss' : train_loss,
        'validation loss' : val_loss
       }
  
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(train_loss, label=r'$train\_loss$')
ax[0].plot(val_loss, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(train_loss1, label=r'$train\_loss$')
ax[1].plot(val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(train_loss2, label=r'$train\_loss$')
ax[2].plot(val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(train_loss3, label=r'$train\_loss$')
ax[3].plot(val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("MOOACS+FedProx for MNIST-nonIID data")
plt.show()
plt.savefig('MOOACS+FedProx for MNIST-nonIID data.png')

# %% [markdown]
# MOOACS+Fedavg+non-IID

# %%
pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

# %%
train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(train_loss, label=r'$train\_loss$')
ax[0].plot(val_loss, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(train_loss1, label=r'$train\_loss$')
ax[1].plot(val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(train_loss2, label=r'$train\_loss$')
ax[2].plot(val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(train_loss3, label=r'$train\_loss$')
ax[3].plot(val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("MOOACS+Fedavg for MNIST-nonIID data")
plt.savefig('MOOACS+Fedavg for MNIST-nonIID data.png')
plt.show()

# %%
pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/Random_mnist_cnn_method[fedavg]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/Random_mnist_cnn_method[fedavg]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/Random_mnist_cnn_method[fedavg]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('/home/gpu-0002/straggler-mitigation-fl/save/Random_mnist_cnn_method[fedavg]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

r_train_loss_sp = pdm_temp[0]
r_val_loss_sp = pdm_temp[1]
r_val_accuracy_sp = pdm_temp[2]
r_test_accuracy_sp = pdm_temp[3][0]
r_test_loss_sp = pdm_temp[3][1]

r_train_loss1_sp = pdm_temp1[0]
r_val_loss1_sp = pdm_temp1[1]
r_val_accuracy1_sp = pdm_temp1[2]
r_test_accuracy1_sp = pdm_temp1[3][0]
r_test_loss1_sp = pdm_temp1[3][1]

r_train_loss2_sp = pdm_temp2[0]
r_val_loss2_sp = pdm_temp2[1]
r_val_accuracy2_sp = pdm_temp2[2]
r_test_accuracy2_sp = pdm_temp2[3][0]
r_test_loss2_sp = pdm_temp2[3][1]

r_train_loss3_sp = pdm_temp3[0]
r_val_loss3_sp = pdm_temp3[1]
r_val_accuracy3_sp = pdm_temp3[2]
r_test_accuracy3_sp = pdm_temp3[3][0]
r_test_loss3_sp = pdm_temp3[3][1]

import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(r_train_loss_sp, label=r'$train\_loss$')
ax[0].plot(r_val_loss_sp, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(r_train_loss1_sp, label=r'$train\_loss$')
ax[1].plot(r_val_loss1_sp, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(r_train_loss2_sp, label=r'$train\_loss$')
ax[2].plot(r_val_loss2_sp, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(r_train_loss3_sp, label=r'$train\_loss$')
ax[3].plot(r_val_loss3_sp, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("Random+Fedavg for MNIST-nonIID data without removing stragglers ")
plt.savefig('Random+Fedavg for MNIST-nonIID data without removing stragglers.png')
plt.show()

# %%
Random+Fedavg

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,3, figsize=(15, 4))

ax[0].plot(val_accuracy, label=r'$straggler\_frac = 0.9%$')
ax[0].plot(val_accuracy1, label=r'$straggler\_frac = 0.7%$')
ax[0].plot(val_accuracy2, label=r'$straggler\_frac = 0.5%$')
ax[0].plot(val_accuracy3, label=r'$straggler\_frac = 0.1%$')

#ax[0].set_yscale('log')
ax[0].set_title("\n Convergence MOOACS+Fedavg \n presence of stragglers")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Accuracy")
ax[0].legend()

ax[1].plot(r_val_accuracy, label=r'$straggler\_frac = 0.9%$')
ax[1].plot(r_val_accuracy1, label=r'$straggler\_frac = 0.7%$')
ax[1].plot(r_val_accuracy2, label=r'$straggler\_frac = 0.5%$')
ax[1].plot(r_val_accuracy3, label=r'$straggler\_frac = 0.1%$')

#ax[0].set_yscale('log')
ax[1].set_title("\n Convergence Random+Fedavg \n by removing stragglers")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

ax[2].plot(r_val_accuracy_sp, label=r'$straggler\_frac = 0.9%$')
ax[2].plot(r_val_accuracy1_sp, label=r'$straggler\_frac = 0.7%$')
ax[2].plot(r_val_accuracy2_sp, label=r'$straggler\_frac = 0.5%$')
ax[2].plot(r_val_accuracy3_sp, label=r'$straggler\_frac = 0.1%$')

#ax[0].set_yscale('log')
ax[2].set_title("\n Convergence Random+Fedavg \n not removing stragglers")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Accuracy")
ax[2].legend()

#fig.suptitle("MOOACS+Fedavg vs random+Fedavg for MNIST-nonIID data \n \n")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d785e707acaa> in <module>
#      26 ax[0].legend()
#      27
# ---> 28 ax[1].plot(r_val_accuracy, label=r'$straggler\_frac = 0.9%$')
#      29 ax[1].plot(r_val_accuracy1, label=r'$straggler\_frac = 0.7%$')
#      30 ax[1].plot(r_val_accuracy2, label=r'$straggler\_frac = 0.5%$')
#
# NameError: name 'r_val_accuracy' is not defined

# %%
pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[1].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()
try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp)

pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[1].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[1].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[1].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

r_train_loss = pdm_temp[0]
r_val_loss = pdm_temp[1]
r_val_accuracy = pdm_temp[2]
r_test_accuracy = pdm_temp[3][0]
r_test_loss = pdm_temp[3][1]

r_train_loss1 = pdm_temp1[0]
r_val_loss1 = pdm_temp1[1]
r_val_accuracy1 = pdm_temp1[2]
r_test_accuracy1 = pdm_temp1[3][0]
r_test_loss1 = pdm_temp1[3][1]

r_train_loss2 = pdm_temp2[0]
r_val_loss2 = pdm_temp2[1]
r_val_accuracy2 = pdm_temp2[2]
r_test_accuracy2 = pdm_temp2[3][0]
r_test_loss2 = pdm_temp2[3][1]

r_train_loss3 = pdm_temp3[0]
r_val_loss3 = pdm_temp3[1]
r_val_accuracy3 = pdm_temp3[2]
r_test_accuracy3 = pdm_temp3[3][0]
r_test_loss3 = pdm_temp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9, 0.7, 0.5, 0.1
 remove straggler : true
 Fraction of participating users: random participation
 Local batch size: 128
 Maximum Local epochs: 10
''' 

 
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(r_train_loss, label=r'$train\_loss$')
ax[0].plot(r_val_loss, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("removed straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(r_train_loss1, label=r'$train\_loss$')
ax[1].plot(r_val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("removed straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(r_train_loss2, label=r'$train\_loss$')
ax[2].plot(r_val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("removed straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(r_train_loss3, label=r'$train\_loss$')
ax[3].plot(r_val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("removed straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("random selection+Fedavg for MNIST-nonIID data")
plt.savefig('random selection+Fedavg for MNIST-nonIID data by removing stragglers.png')
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Dataset : non-IID
 straggler frac : 0.9, 0.7, 0.5, 0.1
 remove straggler : true for random selection fedavg
 remove straggler : false for MOOACS+FedProx 
 Fraction of participating users: random participation
 Local batch size: 128
 Maximum Local epochs: 10
''' 

data = {'training loss' : train_loss,
        'validation loss' : val_loss
       }
  
fig, ax = plt.subplots(1,4, figsize=(20, 5))

ax[0].plot(val_loss, label=r'$val\_loss MOOACS+FedProx$')
ax[0].plot(r_val_loss, label=r'$val\_loss Random+FedAVg$')
#ax[0].set_yscale('log')
ax[0].set_title("removed straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(val_loss1, label=r'$val\_loss MOOACS+FedProx$')
ax[1].plot(r_val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("removed straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(val_loss2, label=r'$val\_loss MOOACS+FedProx$')
ax[2].plot(r_val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("removed straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(val_loss3, label=r'$val\_loss MOOACS+FedProx$')
ax[3].plot(r_val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("removed straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig, ax = plt.subplots(1,4, figsize=(20, 5))

ax[0].plot(val_accuracy, label=r'$Acc MOOACS+FedProx$')
ax[0].plot(r_val_accuracy, label=r'$Acc Random+FedAVg$')
#ax[0].set_yscale('log')
ax[0].set_title("removed straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Accuracy")
ax[0].legend()

ax[1].plot(val_accuracy1, label=r'$Acc MOOACS+FedProx$')
ax[1].plot(r_val_accuracy1, label=r'$Acc Random+FedAVg$')
#ax[0].set_yscale('log')
ax[1].set_title("removed straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

ax[2].plot(val_accuracy2, label=r'$Acc MOOACS+FedProx$')
ax[2].plot(r_val_accuracy2, label=r'$Acc Random+FedAVg$')
#ax[0].set_yscale('log')
ax[2].set_title("removed straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Accuracy")
ax[2].legend()

ax[3].plot(val_accuracy3, label=r'$Acc MOOACS+FedProx$')
ax[3].plot(r_val_accuracy3, label=r'$Acc Random+FedAVg$')
#ax[0].set_yscale('log')
ax[3].set_title("removed straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Accuracy")
ax[3].legend()
fig.suptitle("Comparison between random selection+Fedavg vs MOOACS+FedProx for MNIST-nonIID data")
plt.savefig('Comparison between random selection+Fedavg vs MOOACS+FedProx for MNIST-nonIID data.png')
plt.show()

# %%
pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.9]_iid[0]_LE[10]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp)

# %%
pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[10]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

# %%
pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.1]_iid[0]_LE[10]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

# %%
pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.5]_iid[0]_LE[10]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

# %%
train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

# %%
train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

# %%
train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

# %%
train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
''' 

data = {'training loss' : train_loss,
        'validation loss' : val_loss
       }
  
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(train_loss, label=r'$train\_loss$')
ax[0].plot(val_loss, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(train_loss1, label=r'$train\_loss$')
ax[1].plot(val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(train_loss2, label=r'$train\_loss$')
ax[2].plot(val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(train_loss3, label=r'$train\_loss$')
ax[3].plot(val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("MOOACS+FedProx for MNIST-IID data")
plt.show()

# %%
pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp)

# %%
pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

# %%
pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

# %%
pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

# %%
train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : nonIID
 straggler frac : 0.9, 0.7, 0.5, 0.1
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
''' 

data = {'training loss' : train_loss,
        'validation loss' : val_loss
       }
  
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(train_loss, label=r'$train\_loss$')
ax[0].plot(val_loss, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(train_loss1, label=r'$train\_loss$')
ax[1].plot(val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(train_loss2, label=r'$train\_loss$')
ax[2].plot(val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(train_loss3, label=r'$train\_loss$')
ax[3].plot(val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("MOOACS+FedProx for CIFAR-nonIID data")
plt.show()

# %%
pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp)

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[30].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
#print(pdm_temp1)

train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : IID
 straggler frac : 0.9, 0.7, 0.5, 0.1
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
''' 

data = {'training loss' : train_loss,
        'validation loss' : val_loss
       }
  
fig, ax = plt.subplots(1,4, figsize=(15, 4))

ax[0].plot(train_loss, label=r'$train\_loss$')
ax[0].plot(val_loss, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[0].set_title("straggler fraction = 0.9")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(train_loss1, label=r'$train\_loss$')
ax[1].plot(val_loss1, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[1].set_title("straggler fraction = 0.7")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

ax[2].plot(train_loss2, label=r'$train\_loss$')
ax[2].plot(val_loss2, label=r'$val\_loss$')
#ax[0].set_yscale('log')
ax[2].set_title("straggler fraction = 0.5")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Loss")
ax[2].legend()

ax[3].plot(train_loss3, label=r'$train\_loss$')
ax[3].plot(val_loss3, label=r'$val\_loss$')
#ax0].set_yscale('log')
ax[3].set_title("straggler fraction = 0.1")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Loss")
ax[3].legend()

fig.suptitle("MOOACS+FedProx for CIFAR-IID data")
plt.show()

# %% [markdown]
# comparison between different adaptiveness

# %%
#FedProx + MNIST-IID

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[10].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[15].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[20].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)


#Fed-Prox + MNIST-nonIID 

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[1].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[10].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[15].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[20].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp4 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp4 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]

'''train_loss4 = pdm_temp4[0]
val_loss4 = pdm_temp4[1]
val_accuracy4 = pdm_temp4[2]
test_accuracy4 = pdm_temp4[3][0]
test_loss4 = pdm_temp4[3][1]
'''


train_lossfp = pdm_tempfp[0]
val_lossfp = pdm_tempfp[1]
val_accuracyfp = pdm_tempfp[2]
test_accuracyfp = pdm_tempfp[3][0]
test_lossfp = pdm_tempfp[3][1]

train_lossfp1 = pdm_tempfp1[0]
val_lossfp1 = pdm_tempfp1[1]
val_accuracyfp1 = pdm_tempfp1[2]
test_accuracyfp1 = pdm_tempfp1[3][0]
test_lossfp1 = pdm_tempfp1[3][1]

train_lossfp2 = pdm_tempfp2[0]
val_lossfp2 = pdm_tempfp2[1]
val_accuracyfp2 = pdm_tempfp2[2]
test_accuracyfp2 = pdm_tempfp2[3][0]
test_lossfp2 = pdm_tempfp2[3][1]

train_lossfp3 = pdm_tempfp3[0]
val_lossfp3 = pdm_tempfp3[1]
val_accuracyfp3 = pdm_tempfp3[2]
test_accuracyfp3 = pdm_tempfp3[3][0]
test_lossfp3 = pdm_tempfp3[3][1]

train_lossfp4 = pdm_tempfp4[0]
val_lossfp4 = pdm_tempfp4[1]
val_accuracyfp4 = pdm_tempfp4[2]
test_accuracyfp4 = pdm_tempfp4[3][0]
test_lossfp4 = pdm_tempfp4[3][1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-91-978e5d4718e3> in <module>
#      11 # print(pdm_temp)
#      12
# ---> 13 pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[10].pkl', 'rb')
#      14 # mydict1 = pickle.load(pkl_file)
#      15 # pkl_file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[10].pkl'

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,3, figsize=(15, 4))

ax[0].plot(val_accuracy, label=r'$adaptiveness=1$')
ax[0].plot(val_accuracy4, label=r'$adaptiveness=5$')
ax[0].plot(val_accuracy1, label=r'$adaptiveness=10$')
ax[0].plot(val_accuracy2, label=r'$adaptiveness=15$')
ax[0].plot(val_accuracy3, label=r'$adaptiveness=20$')

#ax[0].set_yscale('log')
ax[0].set_title("\n Convergence MOOACS+Fedprox \n presence of stragglers")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Accuracy")
ax[0].legend()


ax[1].plot(val_accuracy, label=r'$adaptiveness=1$')
ax[1].plot(val_accuracy4, label=r'$adaptiveness=5$')
ax[1].plot(val_accuracy1, label=r'$adaptiveness=10$')
ax[1].plot(val_accuracy2, label=r'$adaptiveness=15$')
ax[1].plot(val_accuracy3, label=r'$adaptiveness=20$')

#ax[0].set_yscale('log')
ax[1].set_title("\n Convergence MOOACS+Fedprox \n presence of stragglers")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Accuracy")
ax[1].legend()
'''
ax[1].plot(r_val_accuracy, label=r'$straggler\_frac = 0.9%$')
ax[1].plot(r_val_accuracy1, label=r'$straggler\_frac = 0.7%$')
ax[1].plot(r_val_accuracy2, label=r'$straggler\_frac = 0.5%$')
ax[1].plot(r_val_accuracy3, label=r'$straggler\_frac = 0.1%$')

#ax[0].set_yscale('log')
ax[1].set_title("\n Convergence Random+Fedavg \n by removing stragglers")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

ax[2].plot(r_val_accuracy_sp, label=r'$straggler\_frac = 0.9%$')
ax[2].plot(r_val_accuracy1_sp, label=r'$straggler\_frac = 0.7%$')
ax[2].plot(r_val_accuracy2_sp, label=r'$straggler\_frac = 0.5%$')
ax[2].plot(r_val_accuracy3_sp, label=r'$straggler\_frac = 0.1%$')

#ax[0].set_yscale('log')
ax[2].set_title("\n Convergence Random+Fedavg \n not removing stragglers")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Accuracy")
ax[2].legend()
'''
#fig.suptitle("MOOACS+Fedavg vs random+Fedavg for MNIST-nonIID data \n \n")

plt.show()

# %% [markdown]
# # Figure1. MOOACS + Fedavg vs MOOACS + FedProx vs Random + FedAvg vs Random + FedPox on MNIST IID data

# %%
#MOOACS + fedavg + Mnist-IID

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[100].pkl', 'rb')
try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()


#MOOACS + fedprox + IID 

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
try:
    pdm_tempfp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)

try:
    pdm_tempfp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_tempfp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_tempfp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()


# Random+fedavg + MNIST-IID



pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()



pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()


pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

# Random+fedprox + MNIST-IID


pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()



pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()


pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]


train_lossfp = pdm_tempfp[0]
val_lossfp = pdm_tempfp[1]
val_accuracyfp = pdm_tempfp[2]
test_accuracyfp = pdm_tempfp[3][0]
test_lossfp = pdm_tempfp[3][1]

train_lossfp1 = pdm_tempfp1[0]
val_lossfp1 = pdm_tempfp1[1]
val_accuracyfp1 = pdm_tempfp1[2]
test_accuracyfp1 = pdm_tempfp1[3][0]
test_lossfp1 = pdm_tempfp1[3][1]

train_lossfp2 = pdm_tempfp2[0]
val_lossfp2 = pdm_tempfp2[1]
val_accuracyfp2 = pdm_tempfp2[2]
test_accuracyfp2 = pdm_tempfp2[3][0]
test_lossfp2 = pdm_tempfp2[3][1]

train_lossfp3 = pdm_tempfp3[0]
val_lossfp3 = pdm_tempfp3[1]
val_accuracyfp3 = pdm_tempfp3[2]
test_accuracyfp3 = pdm_tempfp3[3][0]
test_lossfp3 = pdm_tempfp3[3][1]


train_loss_rfa = pdm_temp_rfa[0]
val_loss_rfa = pdm_temp_rfa[1]
val_accuracy_rfa = pdm_temp_rfa[2]
test_accuracy_rfa = pdm_temp_rfa[3][0]
test_loss_rfa = pdm_temp_rfa[3][1]

train_loss_rfa1 = pdm_temp_rfa1[0]
val_loss_rfa1 = pdm_temp_rfa1[1]
val_accuracy_rfa1 = pdm_temp_rfa1[2]
test_accuracy_rfa1 = pdm_temp_rfa1[3][0]
test_loss_rfa1 = pdm_temp_rfa1[3][1]

train_loss_rfa2 = pdm_temp_rfa2[0]
val_lossf_rfa2 = pdm_temp_rfa2[1]
val_accuracy_rfa2 = pdm_temp_rfa2[2]
test_accuracy_rfa2 = pdm_temp_rfa2[3][0]
test_lossf_rfa2 = pdm_temp_rfa2[3][1]

train_loss_rfa3 = pdm_temp_rfa3[0]
val_loss_rfa3 = pdm_temp_rfa3[1]
val_accuracy_rfa3 = pdm_temp_rfa3[2]
test_accuracy_rfa3 = pdm_temp_rfa3[3][0]
test_loss_rfa3 = pdm_temp_rfa3[3][1]



train_loss_rfp = pdm_temp_rfp[0]
val_loss_rfp = pdm_temp_rfp[1]
val_accuracy_rfp = pdm_temp_rfp[2]
test_accuracy_rfp = pdm_temp_rfp[3][0]
test_loss_rfp = pdm_temp_rfp[3][1]

train_loss_rfp1 = pdm_temp_rfp1[0]
val_loss_rfp1 = pdm_temp_rfp1[1]
val_accuracy_rfp1 = pdm_temp_rfp1[2]
test_accuracy_rfp1 = pdm_temp_rfp1[3][0]
test_loss_rfp1 = pdm_temp_rfp1[3][1]

train_loss_rfp2 = pdm_temp_rfp2[0]
val_lossf_rfp2 = pdm_temp_rfp2[1]
val_accuracy_rfp2 = pdm_temp_rfp2[2]
test_accuracy_rfp2 = pdm_temp_rfp2[3][0]
test_lossf_rfp2 = pdm_temp_rfp2[3][1]

train_loss_rfp3 = pdm_temp_rfp3[0]
val_loss_rfp3 = pdm_temp_rfp3[1]
val_accuracy_rfp3 = pdm_temp_rfp3[2]
test_accuracy_rfp3 = pdm_temp_rfp3[3][0]
test_loss_rfp3 = pdm_temp_rfp3[3][1]


'''train_loss4 = pdm_temp4[0]
val_loss4 = pdm_temp4[1]
val_accuracy4 = pdm_temp4[2]
test_accuracy4 = pdm_temp4[3][0]
test_loss4 = pdm_temp4[3][1]
'''
# Out:
# 'train_loss4 = pdm_temp4[0]\nval_loss4 = pdm_temp4[1]\nval_accuracy4 = pdm_temp4[2]\ntest_accuracy4 = pdm_temp4[3][0]\ntest_loss4 = pdm_temp4[3][1]\n'

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,4, figsize=(22, 4))
#plt.tick_params(labelsize=20)
#plt.legend(["blue", "orange"], prop={"size":20})

ax[0].plot(val_accuracy3, label=r'$straggler\_frac=0.9$')
ax[0].plot(val_accuracy2, label=r'$straggler\_frac=0.7$')
ax[0].plot(val_accuracy1, label=r'$straggler\_frac=0.5$')
ax[0].plot(val_accuracy, label=r'$straggler\_frac=0.1$')

ax[1].plot(val_accuracyfp3, label=r'$straggler\_frac=0.9$')
ax[1].plot(val_accuracyfp2, label=r'$straggler\_frac=0.7$')
ax[1].plot(val_accuracyfp1, label=r'$straggler\_frac=0.5$')
ax[1].plot(val_accuracyfp, label=r'$straggler\_frac=0.1$')

ax[2].plot(val_accuracy_rfa3, label=r'$straggler\_frac=0.9$')
ax[2].plot(val_accuracy_rfa2, label=r'$straggler\_frac=0.7$')
ax[2].plot(val_accuracy_rfa1, label=r'$straggler\_frac=0.5$')
ax[2].plot(val_accuracy_rfa, label=r'$straggler\_frac=0.1$')

ax[3].plot(val_accuracy_rfp3, label=r'$straggler\_frac=0.9$')
ax[3].plot(val_accuracy_rfp2, label=r'$straggler\_frac=0.7$')
ax[3].plot(val_accuracy_rfp1, label=r'$straggler\_frac=0.5$')
ax[3].plot(val_accuracy_rfp, label=r'$straggler\_frac=0.1$')

#ax[0].set_yscale('log')
ax[0].set_title("\n Fed-MOODS+Fedavg",fontsize=18)
ax[0].set_xlabel("Iteration",fontsize=18)
ax[0].set_ylabel("Accuracy",fontsize=18)
ax[0].legend(prop={"size":16})

ax[1].set_title("Fed-MOODS+FedProx",fontsize=18)
ax[1].set_xlabel("Iteration",fontsize=18)
ax[1].set_ylabel("Accuracy",fontsize=18)
ax[1].legend(prop={"size":16})

ax[2].set_title("Random+Fedavg",fontsize=18)
ax[2].set_xlabel("Iteration",fontsize=18)
ax[2].set_ylabel("Accuracy",fontsize=18)
ax[2].legend(prop={"size":16})

ax[3].set_title("Random+FedProx",fontsize=18)
ax[3].set_xlabel("Iteration",fontsize=18)
ax[3].set_ylabel("Accuracy",fontsize=18)
ax[3].legend(prop={"size":16})

#fig.suptitle("Accuracy comparison on IID data")
plt.savefig('Accuracy comparison MNIST-IID.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Figure1. MOOACS + Fedavg vs MOOACS + FedProx vs Random + FedAvg vs Random + FedPox on MNIST non-IID data

# %%
#MOOACS + fedavg + Mnist-nonIID

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedavg]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()


#MOOACS + fedprox + IID 

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
try:
    pdm_tempfp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)

try:
    pdm_tempfp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_tempfp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()

pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_tempfp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()


# Random+fedavg + MNIST-IID



pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()



pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()


pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

# Random+fedprox + MNIST-IID


pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()



pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()


pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]


train_lossfp = pdm_tempfp[0]
val_lossfp = pdm_tempfp[1]
val_accuracyfp = pdm_tempfp[2]
test_accuracyfp = pdm_tempfp[3][0]
test_lossfp = pdm_tempfp[3][1]

train_lossfp1 = pdm_tempfp1[0]
val_lossfp1 = pdm_tempfp1[1]
val_accuracyfp1 = pdm_tempfp1[2]
test_accuracyfp1 = pdm_tempfp1[3][0]
test_lossfp1 = pdm_tempfp1[3][1]

train_lossfp2 = pdm_tempfp2[0]
val_lossfp2 = pdm_tempfp2[1]
val_accuracyfp2 = pdm_tempfp2[2]
test_accuracyfp2 = pdm_tempfp2[3][0]
test_lossfp2 = pdm_tempfp2[3][1]

train_lossfp3 = pdm_tempfp3[0]
val_lossfp3 = pdm_tempfp3[1]
val_accuracyfp3 = pdm_tempfp3[2]
test_accuracyfp3 = pdm_tempfp3[3][0]
test_lossfp3 = pdm_tempfp3[3][1]


train_loss_rfa = pdm_temp_rfa[0]
val_loss_rfa = pdm_temp_rfa[1]
val_accuracy_rfa = pdm_temp_rfa[2]
test_accuracy_rfa = pdm_temp_rfa[3][0]
test_loss_rfa = pdm_temp_rfa[3][1]

train_loss_rfa1 = pdm_temp_rfa1[0]
val_loss_rfa1 = pdm_temp_rfa1[1]
val_accuracy_rfa1 = pdm_temp_rfa1[2]
test_accuracy_rfa1 = pdm_temp_rfa1[3][0]
test_loss_rfa1 = pdm_temp_rfa1[3][1]

train_loss_rfa2 = pdm_temp_rfa2[0]
val_lossf_rfa2 = pdm_temp_rfa2[1]
val_accuracy_rfa2 = pdm_temp_rfa2[2]
test_accuracy_rfa2 = pdm_temp_rfa2[3][0]
test_lossf_rfa2 = pdm_temp_rfa2[3][1]

train_loss_rfa3 = pdm_temp_rfa3[0]
val_loss_rfa3 = pdm_temp_rfa3[1]
val_accuracy_rfa3 = pdm_temp_rfa3[2]
test_accuracy_rfa3 = pdm_temp_rfa3[3][0]
test_loss_rfa3 = pdm_temp_rfa3[3][1]



train_loss_rfp = pdm_temp_rfp[0]
val_loss_rfp = pdm_temp_rfp[1]
val_accuracy_rfp = pdm_temp_rfp[2]
test_accuracy_rfp = pdm_temp_rfp[3][0]
test_loss_rfp = pdm_temp_rfp[3][1]

train_loss_rfp1 = pdm_temp_rfp1[0]
val_loss_rfp1 = pdm_temp_rfp1[1]
val_accuracy_rfp1 = pdm_temp_rfp1[2]
test_accuracy_rfp1 = pdm_temp_rfp1[3][0]
test_loss_rfp1 = pdm_temp_rfp1[3][1]

train_loss_rfp2 = pdm_temp_rfp2[0]
val_lossf_rfp2 = pdm_temp_rfp2[1]
val_accuracy_rfp2 = pdm_temp_rfp2[2]
test_accuracy_rfp2 = pdm_temp_rfp2[3][0]
test_lossf_rfp2 = pdm_temp_rfp2[3][1]

train_loss_rfp3 = pdm_temp_rfp3[0]
val_loss_rfp3 = pdm_temp_rfp3[1]
val_accuracy_rfp3 = pdm_temp_rfp3[2]
test_accuracy_rfp3 = pdm_temp_rfp3[3][0]
test_loss_rfp3 = pdm_temp_rfp3[3][1]

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,4, figsize=(22, 4))
plt.tick_params(labelsize=12)
ax[0].plot(val_accuracy3, label=r'$straggler\_frac=0.9$')
ax[0].plot(val_accuracy2, label=r'$straggler\_frac=0.7$')
ax[0].plot(val_accuracy1, label=r'$straggler\_frac=0.5$')
ax[0].plot(val_accuracy, label=r'$straggler\_frac=0.1$')

ax[1].plot(val_accuracyfp3, label=r'$straggler\_frac=0.9$')
ax[1].plot(val_accuracyfp2, label=r'$straggler\_frac=0.7$')
ax[1].plot(val_accuracyfp1, label=r'$straggler\_frac=0.5$')
ax[1].plot(val_accuracyfp, label=r'$straggler\_frac=0.1$')

ax[2].plot(val_accuracy_rfa3, label=r'$straggler\_frac=0.9$')
ax[2].plot(val_accuracy_rfa2, label=r'$straggler\_frac=0.7$')
ax[2].plot(val_accuracy_rfa1, label=r'$straggler\_frac=0.5$')
ax[2].plot(val_accuracy_rfa, label=r'$straggler\_frac=0.1$')

ax[3].plot(val_accuracy_rfp3, label=r'$straggler\_frac=0.9$')
ax[3].plot(val_accuracy_rfp2, label=r'$straggler\_frac=0.7$')
ax[3].plot(val_accuracy_rfp1, label=r'$straggler\_frac=0.5$')
ax[3].plot(val_accuracy_rfp, label=r'$straggler\_frac=0.1$')

#ax[0].set_yscale('log')
ax[0].set_title("Fed-MOODS+Fedavg")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Accuracy")
ax[0].legend(prop={"size":16})

ax[1].set_title("Fed-MOODS+FedProx")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Accuracy")
ax[1].legend(prop={"size":16})

ax[2].set_title("Random+Fedavg")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Accuracy")
ax[2].legend(prop={"size":16})

ax[3].set_title("Random+FedProx")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Accuracy")
ax[3].legend(prop={"size":16})

#fig.suptitle("Accuracy comparison on IID data")
plt.savefig('Accuracy comparison MNIST-nonIID.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Figure1. MOOACS + Fedavg vs MOOACS + FedProx vs Random + FedAvg vs Random + FedPox on CIFAR10 non-IID data

# %%
#MOOACS + fedavg + CIFAR-nonIID

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedavg]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedavg]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)

try:
    pdm_temp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file.close()

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedavg]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedavg]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_temp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()


#MOOACS + fedprox + CIFAR IID 

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.1]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
try:
    pdm_tempfp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.5]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)

try:
    pdm_tempfp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)

pkl_file.close()

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.7]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_tempfp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()

pkl_file = open('../save/MOOACS_cifar_cnn_method[fedprox]_straggler[0.9]_iid[0]_LE[20]_B[128]_GE[500]_adaptive[5].pkl', 'rb')
# mydict1 = pickle.load(pkl_file)
# pkl_file.close()

try:
    pdm_tempfp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_tempfp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp1)
pkl_file.close()


# Random+fedavg + CIFAR-IID
'''


pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()



pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()


pkl_file = open('../save/Random_mnist_cnn_method[fedavg]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfa3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfa3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

# Random+fedprox + MNIST-IID


pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.1]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.5]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp1 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp1 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()



pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.7]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp2 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp2 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()


pkl_file = open('../save/Random_mnist_cnn_method[fedprox]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_rmstraggler[0].pkl', 'rb')
try:
    pdm_temp_rfp3 = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp_rfp3 = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()'''

train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

train_loss1 = pdm_temp1[0]
val_loss1 = pdm_temp1[1]
val_accuracy1 = pdm_temp1[2]
test_accuracy1 = pdm_temp1[3][0]
test_loss1 = pdm_temp1[3][1]

train_loss2 = pdm_temp2[0]
val_loss2 = pdm_temp2[1]
val_accuracy2 = pdm_temp2[2]
test_accuracy2 = pdm_temp2[3][0]
test_loss2 = pdm_temp2[3][1]

train_loss3 = pdm_temp3[0]
val_loss3 = pdm_temp3[1]
val_accuracy3 = pdm_temp3[2]
test_accuracy3 = pdm_temp3[3][0]
test_loss3 = pdm_temp3[3][1]


train_lossfp = pdm_tempfp[0]
val_lossfp = pdm_tempfp[1]
val_accuracyfp = pdm_tempfp[2]
test_accuracyfp = pdm_tempfp[3][0]
test_lossfp = pdm_tempfp[3][1]

train_lossfp1 = pdm_tempfp1[0]
val_lossfp1 = pdm_tempfp1[1]
val_accuracyfp1 = pdm_tempfp1[2]
test_accuracyfp1 = pdm_tempfp1[3][0]
test_lossfp1 = pdm_tempfp1[3][1]

train_lossfp2 = pdm_tempfp2[0]
val_lossfp2 = pdm_tempfp2[1]
val_accuracyfp2 = pdm_tempfp2[2]
test_accuracyfp2 = pdm_tempfp2[3][0]
test_lossfp2 = pdm_tempfp2[3][1]

train_lossfp3 = pdm_tempfp3[0]
val_lossfp3 = pdm_tempfp3[1]
val_accuracyfp3 = pdm_tempfp3[2]
test_accuracyfp3 = pdm_tempfp3[3][0]
test_lossfp3 = pdm_tempfp3[3][1]

'''
train_loss_rfa = pdm_temp_rfa[0]
val_loss_rfa = pdm_temp_rfa[1]
val_accuracy_rfa = pdm_temp_rfa[2]
test_accuracy_rfa = pdm_temp_rfa[3][0]
test_loss_rfa = pdm_temp_rfa[3][1]

train_loss_rfa1 = pdm_temp_rfa1[0]
val_loss_rfa1 = pdm_temp_rfa1[1]
val_accuracy_rfa1 = pdm_temp_rfa1[2]
test_accuracy_rfa1 = pdm_temp_rfa1[3][0]
test_loss_rfa1 = pdm_temp_rfa1[3][1]

train_loss_rfa2 = pdm_temp_rfa2[0]
val_lossf_rfa2 = pdm_temp_rfa2[1]
val_accuracy_rfa2 = pdm_temp_rfa2[2]
test_accuracy_rfa2 = pdm_temp_rfa2[3][0]
test_lossf_rfa2 = pdm_temp_rfa2[3][1]

train_loss_rfa3 = pdm_temp_rfa3[0]
val_loss_rfa3 = pdm_temp_rfa3[1]
val_accuracy_rfa3 = pdm_temp_rfa3[2]
test_accuracy_rfa3 = pdm_temp_rfa3[3][0]
test_loss_rfa3 = pdm_temp_rfa3[3][1]



train_loss_rfp = pdm_temp_rfp[0]
val_loss_rfp = pdm_temp_rfp[1]
val_accuracy_rfp = pdm_temp_rfp[2]
test_accuracy_rfp = pdm_temp_rfp[3][0]
test_loss_rfp = pdm_temp_rfp[3][1]

train_loss_rfp1 = pdm_temp_rfp1[0]
val_loss_rfp1 = pdm_temp_rfp1[1]
val_accuracy_rfp1 = pdm_temp_rfp1[2]
test_accuracy_rfp1 = pdm_temp_rfp1[3][0]
test_loss_rfp1 = pdm_temp_rfp1[3][1]

train_loss_rfp2 = pdm_temp_rfp2[0]
val_lossf_rfp2 = pdm_temp_rfp2[1]
val_accuracy_rfp2 = pdm_temp_rfp2[2]
test_accuracy_rfp2 = pdm_temp_rfp2[3][0]
test_lossf_rfp2 = pdm_temp_rfp2[3][1]

train_loss_rfp3 = pdm_temp_rfp3[0]
val_loss_rfp3 = pdm_temp_rfp3[1]
val_accuracy_rfp3 = pdm_temp_rfp3[2]
test_accuracy_rfp3 = pdm_temp_rfp3[3][0]
test_loss_rfp3 = pdm_temp_rfp3[3][1]'''
# Out:
# '\ntrain_loss_rfa = pdm_temp_rfa[0]\nval_loss_rfa = pdm_temp_rfa[1]\nval_accuracy_rfa = pdm_temp_rfa[2]\ntest_accuracy_rfa = pdm_temp_rfa[3][0]\ntest_loss_rfa = pdm_temp_rfa[3][1]\n\ntrain_loss_rfa1 = pdm_temp_rfa1[0]\nval_loss_rfa1 = pdm_temp_rfa1[1]\nval_accuracy_rfa1 = pdm_temp_rfa1[2]\ntest_accuracy_rfa1 = pdm_temp_rfa1[3][0]\ntest_loss_rfa1 = pdm_temp_rfa1[3][1]\n\ntrain_loss_rfa2 = pdm_temp_rfa2[0]\nval_lossf_rfa2 = pdm_temp_rfa2[1]\nval_accuracy_rfa2 = pdm_temp_rfa2[2]\ntest_accuracy_rfa2 = pdm_temp_rfa2[3][0]\ntest_lossf_rfa2 = pdm_temp_rfa2[3][1]\n\ntrain_loss_rfa3 = pdm_temp_rfa3[0]\nval_loss_rfa3 = pdm_temp_rfa3[1]\nval_accuracy_rfa3 = pdm_temp_rfa3[2]\ntest_accuracy_rfa3 = pdm_temp_rfa3[3][0]\ntest_loss_rfa3 = pdm_temp_rfa3[3][1]\n\n\n\ntrain_loss_rfp = pdm_temp_rfp[0]\nval_loss_rfp = pdm_temp_rfp[1]\nval_accuracy_rfp = pdm_temp_rfp[2]\ntest_accuracy_rfp = pdm_temp_rfp[3][0]\ntest_loss_rfp = pdm_temp_rfp[3][1]\n\ntrain_loss_rfp1 = pdm_temp_rfp1[0]\nval_loss_rfp1 = pdm_tem
# ...

# %%
import pandas as pd  
import matplotlib.pyplot as plt
'''
 Model : cnn
 Optimizer : sgd
 learning rate : 0.01
 Global Rounds : 30
 Federated settings
 Dataset : non-IID
 straggler frac : 0.9
 Fraction of participating users: adaptive participation
 Local batch size: 128
 Maximum Local epochs: 10
'''   
fig, ax = plt.subplots(1,4, figsize=(17, 2.5))

ax[0].plot(val_accuracy3, label=r'$straggler\_frac=0.9$')
ax[0].plot(val_accuracy2, label=r'$straggler\_frac=0.7$')
ax[0].plot(val_accuracy1, label=r'$straggler\_frac=0.5$')
ax[0].plot(val_accuracy, label=r'$straggler\_frac=0.1$')

ax[1].plot(val_accuracyfp3, label=r'$straggler\_frac=0.9$')
ax[1].plot(val_accuracyfp2, label=r'$straggler\_frac=0.7$')
ax[1].plot(val_accuracyfp1, label=r'$straggler\_frac=0.5$')
ax[1].plot(val_accuracyfp, label=r'$straggler\_frac=0.1$')

'''ax[2].plot(val_accuracy_rfa3, label=r'$straggler\_frac=0.9$')
ax[2].plot(val_accuracy_rfa2, label=r'$straggler\_frac=0.7$')
ax[2].plot(val_accuracy_rfa1, label=r'$straggler\_frac=0.5$')
ax[2].plot(val_accuracy_rfa, label=r'$straggler\_frac=0.1$')

ax[3].plot(val_accuracy_rfp3, label=r'$straggler\_frac=0.9$')
ax[3].plot(val_accuracy_rfp2, label=r'$straggler\_frac=0.7$')
ax[3].plot(val_accuracy_rfp1, label=r'$straggler\_frac=0.5$')
ax[3].plot(val_accuracy_rfp, label=r'$straggler\_frac=0.1$')'''

#ax[0].set_yscale('log')
ax[0].set_title("\n Convergence comparison \n  MOOACS+Fedavg on \n MNIST-nonIID data \n presence of stragglers")
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Accuracy")
ax[0].legend(prop={"size":16})

ax[1].set_title("\n Convergence comparison \n MOOACS+FedProx on \n MNIST-nonIID data \n presence of stragglers")
ax[1].set_xlabel("Iteration")
ax[1].set_ylabel("Accuracy")
ax[1].legend(prop={"size":16})

'''ax[2].set_title("\n Convergence comparison \n Random+Fedavg on \n MNIST-nonIID data \n presence of stragglers")
ax[2].set_xlabel("Iteration")
ax[2].set_ylabel("Accuracy")
ax[2].legend()

ax[3].set_title("\n Convergence comparison \n Random+FedProx on \n MNIST-nonIID data \n presence of stragglers")
ax[3].set_xlabel("Iteration")
ax[3].set_ylabel("Accuracy")
ax[3].legend()'''

#fig.suptitle("Accuracy comparison on IID data")
plt.savefig('Accuracy comparison CIFAR10-nonIID.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # F1-score evaluation

# %%
import matplotlib.pyplot as plt
import pandas as pd  
import numpy as np

# %%
data = [94.41, 93.27, 94.00, 97, 96.28]
  
bars =('Fed-MOODS+ \n FedProx', 'Fed-MOODS+ \n FedAvg', 'Random \n selection+ \nFedAvg by \n incorporating \n stragglers' ,'Fed-MOODS+ \n FedAvg \n by \n removing \n stragglers', 'Random \n device \n selection + \n FedAvg \n by \n removing Stragglers')

x_pos = np.arange(len(bars))
plt.bar(bars, data, color = ['green', 'blue','purple', 'grey','red'], width=0.5)
plt.xticks(rotation=0)
plt.xticks(fontsize=10) #, weight = 'bold')
plt.ylim(65,100)

plt.yticks(fontsize = 10) #, weight = 'bold')
#plt.legend(["Clust. of 2", "Clust. of 3","Clust. of 4", "Clust. of 5" ], prop={"size":17},loc='9',ncol=2, bbox_to_anchor=(0.5, 0.53, 0.5, 0.5) )
plt.ylabel("F1-Score",fontsize=12)
plt.xlabel("Method",fontsize= 12) #,fontweight='bold')
#plt.title("Distribution of Data into different hospitals")
plt.savefig('performance_iid_MNIST.pdf',bbox_inches = 'tight')

# %%
data = [93.41, 94.27, 93.00, 70.08]
  
bars =('Fed-MOODS+ \n FedProx', 'Fed-MOODS+ \n FedAvg', 'Random \n selection+ \nFedAvg by \n incorporating \n stragglers' ,  'Random \n device \n selection + \n FedAvg \n by \n removing Stragglers')

x_pos = np.arange(len(bars))
plt.bar(bars, data, color = ['green', 'blue','purple','red'], width=.5)
plt.xticks(rotation=0)
plt.xticks(fontsize=12) #, weight = 'bold')
plt.ylim(65,100)

plt.yticks(fontsize = 12) #, weight = 'bold')
#plt.legend(["Clust. of 2", "Clust. of 3","Clust. of 4", "Clust. of 5" ], prop={"size":17},loc='9',ncol=2, bbox_to_anchor=(0.5, 0.53, 0.5, 0.5) )
plt.ylabel("F1-Score",fontsize=12)
plt.xlabel("Method",fontsize= 12) #,fontweight='bold')
#plt.title("Distribution of Data into different hospitals")
plt.savefig('performance_noniid_MNIST.pdf',bbox_inches = 'tight')

# %%
data = [48.65, 52.92, 49.51, 51.79, 49.67]
  
bars =('Fed-MOODS+ \n FedProx', 'Fed-MOODS+ \n FedAvg', 'Random \n selection+ \nFedAvg by \n incorporating \n stragglers' ,'Fed-MOODS+ \n FedAvg \n by \n removing \n stragglers', 'Random \n device \n selection + \n FedAvg \n by \n removing Stragglers')

x_pos = np.arange(len(bars))
plt.bar(bars, data, color = ['green', 'blue','purple', 'grey','red'], width=0.5)
plt.xticks(rotation=0)
plt.xticks(fontsize=10) #, weight = 'bold')
plt.ylim(0,60)

plt.yticks(fontsize = 10) #, weight = 'bold')
#plt.legend(["Clust. of 2", "Clust. of 3","Clust. of 4", "Clust. of 5" ], prop={"size":17},loc='9',ncol=2, bbox_to_anchor=(0.5, 0.53, 0.5, 0.5) )
plt.ylabel("F1-Score",fontsize=12)
plt.xlabel("Method",fontsize= 12) #,fontweight='bold')
#plt.title("Distribution of Data into different hospitals")
plt.savefig('performance_iid_CIFAR.pdf',bbox_inches = 'tight')

# %%
data = [49.33, 48.79, 9.37, 5.1]
  
bars =('Fed-MOODS+ \n FedProx', 'Fed-MOODS+ \n FedAvg', 'Random \n selection+ \nFedAvg by \n incorporating \n stragglers' ,  'Random \n device \n selection + \n FedAvg \n by \n removing Stragglers')

x_pos = np.arange(len(bars))
plt.bar(bars, data, color = ['green', 'blue','purple','red'], width=.5)
plt.xticks(rotation=0)
plt.xticks(fontsize=12) #, weight = 'bold')
plt.ylim(0,60)

plt.yticks(fontsize = 12) #, weight = 'bold')
#plt.legend(["Clust. of 2", "Clust. of 3","Clust. of 4", "Clust. of 5" ], prop={"size":17},loc='9',ncol=2, bbox_to_anchor=(0.5, 0.53, 0.5, 0.5) )
plt.ylabel("F1-Score",fontsize=12)
plt.xlabel("Method",fontsize= 12) #,fontweight='bold')
#plt.title("Distribution of Data into different hospitals")
plt.savefig('performance_noniid_CIFAR.pdf',bbox_inches = 'tight')

# %% [markdown]
# # best to worst vs worst to best

# %%
MOOACS_mnist_cnn_method[fedprox]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[1].pkl

# %%
import pandas as pd  
import matplotlib.pyplot as plt
pkl_file = open('../save/MOOACS_mnist_cnn_method[fedprox]_straggler[0.9]_iid[1]_LE[20]_B[128]_GE[100]_adaptive[1].pkl', 'rb')
try:
    pdm_temp = pickle.load(pkl_file)
except UnicodeDecodeError:
    pdm_temp = pickle.load(pkl_file, fix_imports=True, encoding="latin1")
# print(pdm_temp)
pkl_file.close()

train_loss = pdm_temp[0]
val_loss = pdm_temp[1]
val_accuracy = pdm_temp[2]
test_accuracy = pdm_temp[3][0]
test_loss = pdm_temp[3][1]

val_accu_wtob = [9.00, 20.37, 18.57, 9, 18.52, 10.85, 20.08, 19.03, 22.35, 21.38, 29.28,
                 27.88, 30.8, 30.23, 39.35, 34.17, 38.28, 35.87, 44.95, 43.78, 53.58, 48.02,
                 54.05, 53.38, 56.48, 57.65, 57.75, 58.83, 59.30, 60.13, 61.23, 62.93, 64.70,
                 65.85, 65.83, 67.85, 68.38, 69.85, 71.20, 72.70, 72.70, 74.20, 75.35, 76.15,
                 77.38, 77.97, 78.85, 78.88, 79.75, 80.07, 80.83, 81.78, 83.00, 82.93, 82.72, 
                 83.83, 82.93, 83.70, 84.12, 84, 84.80, 84.52, 85.77, 85.02, 84.57, 84.87, 85.47,
                 85.85, 85.62, 85.03, 85.78, 85.40, 85.78, 85.72, 86.22, 86.12, 86.45, 87.07,
                 87.08, 87.20, 87.30, 87.30, 87.57, 87.78, 87.62, 87.80, 87.85, 87.92, 88.42, 
                 89.07, 88.90, 89.65, 89.42, 89.87, 89.80, 89.82, 89.85, 90.30]

fig, ax = plt.subplots(1,2, figsize=(17, 2.5))

ax[0].plot(val_accu_wtob, label=r'$worst \ to \ best$')
ax[0].plot(val_accuracy, label=r'$best\ to \ worst$')
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Validation accuracy")
ax[0].legend()
plt.savefig('Accuracy comparison MNIST-nonIID-wtoB.pdf',bbox_inches='tight')
plt.show()
